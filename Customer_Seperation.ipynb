# %%
#Data visualization
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("Mall_Customers.csv")
# print(df)
df.head(9)

# %%
df.shape
# df.info()


# df.isnull().sum()
# Out:
# (200, 5)

# %%
df_update = df.drop(["CustomerID", "Age", "Gender"], axis = 1)
df_update

inertia = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init = 'k-means++', random_state = 42 )
    kmeans.fit(df_update)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\Akshat\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Akshat\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Akshat\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
sns.set()
plt.plot(range(1,11), wcss)
plt.title("The Elbow Point Graph")
plt.xlabel("Cluster")
plt.ylabel("Inertia")
# Out:
# Text(0, 0.5, 'Inertia')

# %%
model = KMeans(n_clusters = 5,random_state = 42,  init ='k-means++')
df_update["Cluster_groups"] = model.fit_predict(df_update) +1
df_update
# Out:
# C:\Users\Akshat\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#      Annual Income (k$)  Spending Score (1-100)  Cluster_groups
# 0                    15                      39               5
# 1                    15                      81               3
# 2                    16                       6               5
# 3                    16                      77               3
# 4                    17                      40               5
# ..                  ...                     ...             ...
# 195                 120                      79               2
# 196                 126                      28               4
# 197                 126                      74               2
# ...

# %%
# Sort the DataFrame by the new 'Cluster_Label' column
df_sorted = df_update.sort_values(by='Cluster_groups')
print(df_sorted)
# df_sorted.head(15)
# Out:
#     Annual Income (k$)  Spending Score (1-100)  Cluster_groups
# 48                  40                      42               1
# 49                  40                      42               1
# 50                  42                      52               1
# 51                  42                      60               1
# 52                  43                      54               1
# ..                 ...                     ...             ...
# 26                  28                      32               5
# 18                  23                      29               5
# 16                  21                      35               5
# 20                  24                      35               5
# 22                  25                       5               5
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data = df_update, x="Annual Income (k$)", y= "Spending Score (1-100)",hue="Cluster_groups")
plt.title("Data Visualisation")
# Out:
# Text(0.5, 1.0, 'Data Visualisation')
